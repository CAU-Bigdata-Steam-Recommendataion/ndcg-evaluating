# %%
# %pip install lightfm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightfm in /usr/local/lib/python3.8/dist-packages (1.16)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from lightfm) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from lightfm) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from lightfm) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from lightfm) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->lightfm) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lightfm) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->lightfm) (1.2.0)

# %%
import time
import os
import zipfile
import csv
import requests
import json
from itertools import islice

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from lightfm.data import Dataset
from lightfm import LightFM
from lightfm.evaluation import precision_at_k
from lightfm.evaluation import auc_score
from lightfm.cross_validation import random_train_test_split 

from scipy.sparse import coo_matrix as sp

import warnings # warings 제거
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 초기설정시 기본 환경설정

# %%
# %cd drive/MyDrive

# %%
# %mkdir steam

# %%
# %cd steam
# Out:
# /content/drive/MyDrive/steam

# %%
# !unzip 'steam.zip'
# Out:
# Archive:  steam.zip
#   inflating: parsed_data.csv
#   inflating: parsed_data_only_games.csv
#   inflating: parsed_data_overten.csv
#   inflating: steam_store_data.json
#   inflating: Steam_store_data.pptx
#   inflating: ~$Steam_store_data.pptx

# %%
# 데이터 로드 (type : dataframe)

# %%
with open('/content/drive/MyDrive/steam/steam_store_data.json', 'r') as game_data:
    game_data = pd.read_json(game_data)

# %%
with open('/content/drive/MyDrive/steam/parsed_data_overten_reset.csv', 'r') as review_data:
    review_data = pd.read_csv(review_data)

# %% [markdown]
# # 1. Data structure and embedding

# %% [markdown]
# > ## Data loading, preprocessing

# %% [markdown]
# **user_features** : user의 특성(예시: 성별, 지역, 선호유형)
#
# **item_features**: item의 특성(예시: 제목, 가격, 장르, 국가, 게시 시간)
#
# **interactions** : user-item간의 data(평점)

# %% [markdown]
# > ## 데이터프레임 형태 변형 및 확인

# %%
game_data = game_data.transpose() # 행렬 뒤집기

# %%
game_data.head()
# Out:
#          type                              name steam_appid required_age  \
# 570      game                            Dota 2         570            0
# 730      game  Counter-Strike: Global Offensive         730            0
# 578080   game               PUBG: BATTLEGROUNDS      578080            0
# 1063730  game                         New World     1063730            0
# 440      game                   Team Fortress 2         440            0
#
#         is_free                dlc  \
# 570        True  [1241930, 652720]
# 730        True          [1766730]
# 578080     True                NaN
# 1063730   False                NaN
# 440        True           [629330]
#
#                                       detailed_description  \
# 570      <strong>The most-played game on Steam.</strong...
# 730      Counter-Strike: Global Offensive (CS: GO) expa...
# 578080   <strong>LAND, LOOT, SURVIVE!</strong><br>Play ...
# 1063730  <h1>New World -  Deluxe Edition</h1><p><img sr...
# 440      <p><strong>"The most fun you can have online"<...
#
#                                             about_the_game  \
# 570      <strong>The most-played game on Steam.</strong...
# 730      Counter-Strike: Global Offensive (CS: GO) expa...
# 578080   <strong>LAND, LOOT, SURVIVE!</strong><br>Play ...
# 1063730  Explore a thrilling, open-world MMO filled wit...
# 440      <p><strong>"The most fun you can have online"<...
#
#                                          short_description  \
# 570      Every day, millions of players worldwide enter...
# 730      Counter-Strike: Global Offensive (CS: GO) expa...
# 578080   Play PUBG: BATTLEGROUNDS for free. Land on str...
# 1063730  Explore a thrilling, open-world MMO filled wit...
# 440      Nine distinct classes provide a broad range of...
#
#                                        supported_languages  ...  \
# 570      Bulgarian, Czech, Danish, Dutch, English<stron...  ...
# 730      Czech, Danish, Dutch, English<strong>*</strong...  ...
# 578080   English, Korean, Simplified Chinese, French, G...  ...
# 1063730  English<strong>*</strong>, French<strong>*</st...  ...
# 440      English<strong>*</strong>, Danish, Dutch, Finn...  ...
#
#                                                 background  \
# 570      https://cdn.akamai.steamstatic.com/steam/apps/...
# 730      https://cdn.akamai.steamstatic.com/steam/apps/...
# 578080   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1063730  https://cdn.akamai.steamstatic.com/steam/apps/...
# 440      https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                             background_raw  \
# 570      https://cdn.akamai.steamstatic.com/steam/apps/...
# 730      https://cdn.akamai.steamstatic.com/steam/apps/...
# 578080   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1063730  https://cdn.akamai.steamstatic.com/steam/apps/...
# 440      https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                        content_descriptors controller_support  \
# 570                             {'ids': [], 'notes': None}                NaN
# 730      {'ids': [2, 5], 'notes': 'Includes intense vio...               full
# 578080                      {'ids': [2, 5], 'notes': None}                NaN
# 1063730  {'ids': [2, 5], 'notes': 'This Game may contai...                NaN
# 440      {'ids': [2, 5], 'notes': 'Includes cartoon vio...                NaN
#
#                                               achievements  \
# 570                                                    NaN
# 730      {'total': 167, 'highlighted': [{'name': 'Someo...
# 578080   {'total': 37, 'highlighted': [{'name': 'Last S...
# 1063730  {'total': 133, 'highlighted': [{'name': 'Repai...
# 440      {'total': 520, 'highlighted': [{'name': 'Head ...
#
#                                               legal_notice       drm_notice  \
# 570                                                    NaN              NaN
# 730                                                    NaN              NaN
# 578080   © 2017 KRAFTON, Inc.<br />\r\nPUBG: BATTLEGROU...              NaN
# 1063730  © 2021, Amazon.com, Inc. or its affiliates. Al...  Easy Anti-Cheat
# 440                                                    NaN              NaN
#
#                                             price_overview  \
# 570                                                    NaN
# 730                                                    NaN
# 578080                                                 NaN
# 1063730  {'currency': 'USD', 'initial': 3999, 'final': ...
# 440                                                    NaN
#
#         ext_user_account_notice demos
# 570                         NaN   NaN
# 730                         NaN   NaN
# 578080                      NaN   NaN
# 1063730                     NaN   NaN
# 440                         NaN   NaN
#
# [5 rows x 39 columns]

# %%
game_data.columns

# %%
game_data = game_data[['steam_appid', 'name']]

# %%
review_data = review_data[['author', 'appid', 'playtime_forever', 'playtime_at_review', 'voted_up', 'votes_up']]

# %%
review_data.head()
# Out:
#               author  appid  playtime_forever  playtime_at_review  voted_up  \
# 0  76561198976638577     10             104.0                  10      True
# 1  76561198391972225     10             426.0                 426      True
# 2  76561198414408167     10             386.0                 199      True
# 3  76561198376936422     10             165.0                 184      True
# 4  76561198905733625     10              28.0                  40      True
#
#    votes_up
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
# 변수명 명시적으로 변경함

ratings = review_data 
games = game_data

# %%
# ratings['author']의 타입이 numpy.int64 이므로 str로 변환

# %%
ratings['author'] = ratings['author'].astype('str')

# %% [markdown]
# > ## Data embedding
# 위의 데이터를 embedding dataset으로 build

# %%
# 데이터프레임 중복 확인

# %%
ratings.shape[0]

# %%
ratings.drop_duplicates(inplace = True) # 14916136 -> 13828950로 중복 행 제거

# %%
games.shape[0]

# %%
games.drop_duplicates(inplace = True) # 51936 -> 51927로 중복 행 제거

# %%
# user-item 사이의 interactions matrix 생성

# %%
uf = []

playtime_forever = ratings[['playtime_forever']]
playtime_forever.drop_duplicates(inplace = True)

for i in range(playtime_forever.shape[0]):
  uf.append('playtime_forever:{0}'.format(playtime_forever.iloc[i][0]))

# %%
dataset = Dataset()
dataset.fit(users=ratings['author'],items=ratings['appid'],user_features = uf)

# %%
ratings_source = ratings[['author', 'appid']].values.tolist() # interactions 빌드에 필요한 컬럼만 추출

# %%
interactions, weights = dataset.build_interactions(ratings_source)

# %%
# user_features 빌드

# %%
user_features_source = ratings[['author', 'playtime_forever']]
user_features_source.drop_duplicates(inplace = True)

# %%
user_features_source = user_features_source[['author', 'playtime_forever']].values.tolist()

# %%
user_features_source = [[i[0], ['playtime_forever:{0}'.format(i[1])]] for i in user_features_source]

# %%
user_features=dataset.build_user_features(user_features_source)

# %% [markdown]
# # 2. LightFM Model Function

# %% [markdown]
# > ## Model fit, optimize

# %% [markdown]
# loss function 으로  WARP ,  정확도는 precision@k 를 사용하여 evalutation 을 해준다.

# %%
# 모델 생성 및 학습시킴

# %%
model = LightFM(loss='warp') 
train, test = random_train_test_split(interactions=interactions, test_percentage=0.25) # test_percentage 0.2 -> 0.25
model.fit(train, item_features=None, user_features=user_features, epochs = 10, num_threads = 4) # 에포크 2회 -> 10회

# %%
# precision at k 방식으로 평가

# %%
train_precision = precision_at_k(model, train, k=5, item_features=None,user_features=user_features, num_threads = 4).mean()

# %%
test_precision = precision_at_k(model, test, k=10, item_features=None,user_features=user_features, num_threads = 4).mean()

# %%
print( 'Precision: train %.4f, test %.4f' 
      % ( train_precision,test_precision ))
# Out:
# Precision: train 0.1286, test 0.0376

# %%
# auc 방식으로 평가

# %%
train_auc = auc_score(model, train, item_features=None,user_features=user_features).mean()

# %%
test_auc = auc_score(model, test, item_features=None,user_features=user_features).mean()

# %%
print( 'AUC: train %.4f, test %.4f.' 
      % ( train_auc, test_auc))

# %%
# ndcg_score 평가 방법 추가(아직 적용 안함)

# %%
# %pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn) (1.2.0)

# %%
from sklearn.metrics import ndcg_score

# %% [markdown]
# 추천에서는 성능 지표로 precision@k 를 많이 사용하고
#
# Precision@5 = 0.05 (test) 는 순위로 rank 가 된 게임 중 (k=) 5번째 내에 관심 있을 게임이 나올 정확도가 평균 5% 라는 것입니다. 수치가 매우 낮아보이지만, user/content 수가 많은 real 환경에서 5%를 넘기는 어렵다.
# ​
#
# AUC는 모델의 전체 적인 성능을 나타내는 지표이다.
#
# ​

# %%
# git 명령어

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git add .
# Out:
# warning: adding embedded git repository: drive/MyDrive/LightFM
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> drive/MyDrive/LightFM
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached drive/MyDrive/LightFM
# hint:
# hint: See "git help submodule" for more information.
# error: open("drive/MyDrive/제목 없는 프레젠테이션 (1).gslides"): Operation not supported
# error: unable to index file drive/MyDrive/제목 없는 프레젠테이션 (1).gslides
# fatal: adding files failed

# %%
# !git commit -m "[Feature] 추천시스템 구현 수정"

# %%
# !git push origin main

# %% [markdown]
# > ## Predict score & Recommend games

# %%
# labels = np.array(ratings['appid'])

# def recommendation(model, data, to_recommend):

#     n_users, n_items = data.shape

#     # build a structure to store user scores for each item
#     all_scores = np.empty(shape=(0, n_items))
#     scores = model.predict(to_recommend, np.arange(n_items), item_features = None, user_features = user_features) 
#     top_items_for_user = labels[np.argsort(-scores)] #argsort():오름차순인덱스반환
#     all_scores = np.vstack((all_scores, scores))

#     #compute the average rating for each item in the group
#     item_averages = np.mean(all_scores.astype(np.float), axis=0)
#     top_items_for_group = labels[np.argsort(-item_averages)]
#     top_items_scores=item_averages[np.argsort(-item_averages)]

#     return  top_items_for_user, top_items_scores

# %% [markdown]
# *   group에 author id를 입력하면 모든 games 의 예측 평점을 계산하고
# ex) user 1 -> group = [0], user 2 = group = [1]
# *   list_no에 원하는 게임 수를 입력하면 높은순으로 games(id:score)를 리턴합니다.

# %%
# to_recommend = str(input())
# list_no = 5 # precision at k 토대로 k인 5개로 임의로 정함

# top_items_for_group, top_items_scores = recommendation(model, interactions, to_recommend)

# recommend_steam=pd.DataFrame(columns=games.columns)
# for x in list[:list_no]: 
#   recommend_steam=recommend_steam.append(games[games['steam_appid']== x], ignore_index=True)

# recommend_steam['predict_score']= top_items_scores[:list_no]
# recommend_steam
# Out:
# 76561198976638577
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-9f69f3e4670a> in <module>
#       2 list_no = 5 # precision at k 토대로 k인 5개로 임의로 정함
#       3
# ----> 4 top_items_for_group, top_items_scores = recommendation(model, interactions, to_recommend)
#       5
#       6 recommend_steam=pd.DataFrame(columns=games.columns)
#
# <ipython-input-120-cd0760c12403> in recommendation(model, data, to_recommend)
#       7     # build a structure to store user scores for each item
#       8     all_scores = np.empty(shape=(0, n_items))
# ----> 9     scores = model.predict(to_recommend, np.arange(n_items), item_features = None, user_features = user_features)
#      10     top_items_for_user = labels[np.argsort(-scores)] #argsort():오름차순인덱스반환
#      11     all_scores = np.vstack((all_scores, scores))
#
# /usr/local/lib/python3.8/dist-packages/lightfm/lightfm.py in predict(self, user_ids, item_ids, item_features, user_features, num_threads)
#     786
#     787         if not isinstance(user_ids, np.ndarray):
# --> 788             raise TypeError(
#     789                 f"Invalid type passed to user_ids parameter. "
#     790                 f"This must be either int or np.int32 array. "
#
# TypeError: Invalid type passed to user_ids parameter. This must be either int or np.int32 array. Type received: <class 'str'>
